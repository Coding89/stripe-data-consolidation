# %% [markdown]
# ## Recurring Donations
#
# ### Overview
#
# Analyse a single recurring donor transaction.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_parquet('full_data.parquet', engine="pyarrow")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1057 entries, 0 to 1056
# Data columns (total 10 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   balance_transaction_id                         1057 non-null   object
#  1   description                                    1057 non-null   object
#  2   created_utc                                    1057 non-null   datetime64[ns]
#  3   amount                                         1037 non-null   float64
#  4   currency                                       1057 non-null   object
#  5   fee                                            1057 non-null   float64
#  6   customer_id                                    920 non-null    object
#  7   customer_email                                 991 non-null    object
#  8   customer_name                                  991 non-null    object
#  9   payment_metadata[donorbox_recurring_donation]  1037 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 82.7+ KB

# %% [markdown]
# Filtering certain `customer_id`.
#
# `sort_values` by `created_utc` datetime value
#
# View the top and bottom of the `df`

# %%
df=df.loc[df["customer_id"].notnull()]

df.to_csv("recurring_donors.csv")

unique_customers=set(df["customer_id"].tolist())

print(len(unique_customers))

fig, ax = plt.subplots(figsize=(10,10), facecolor="grey", layout="tight")
df.plot(x="created_utc", y="amount", kind="scatter", ax=ax, c="red", marker="x", markersize=0.5)


#for customer in unique_customers:
    #customer_df = df.loc[df["customer_id"] == customer]
 
    #df.sort_values(by="created_utc", inplace=True, ascending=True)
# Out:
# 33
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 8
#       5 print(len(unique_customers))
#       7 fig, ax = plt.subplots(figsize=(10,10), facecolor="grey", layout="tight")
# ----> 8 df.plot(x="created_utc", y="amount", kind="scatter", ax=ax, c="red", marker="x", markersize=0.5)
#      11 #for customer in unique_customers:
#      12     #customer_df = df.loc[df["customer_id"] == customer]
#      13
#      14     #df.sort_values(by="created_utc", inplace=True, ascending=True)
#
# File c:\Users\Mamiko\Desktop\Life Raft International\stripe-data-consolidation\.venv\lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     973 if kind in self._dataframe_kinds:
#     974     if isinstance(data, ABCDataFrame):
# --> 975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
#     977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File c:\Users\Mamiko\Desktop\Life Raft International\stripe-data-consolidation\.venv\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\Mamiko\Desktop\Life Raft International\stripe-data-consolidation\.venv\lib\site-packages\pandas\plotting\_matplotlib\core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File c:\Users\Mamiko\Desktop\Life Raft International\stripe-data-consolidation\.venv\lib\site-packages\pandas\plotting\_matplotlib\core.py:1351, in ScatterPlot._make_plot(self, fig)
#    1349 else:
#    1350     label = None
# -> 1351 scatter = ax.scatter(
#    1352     data[x].values,
#    1353     data[y].values,
#    1354     c=c_values,
#    1355     label=label,
#    1356     cmap=cmap,
#    1357     norm=norm,
#    1358     s=self.s,
#    1359     **self.kwds,
#    1360 )
#    1361 if cb:
#    1362     cbar_label = c if c_is_column else ""
#
# File c:\Users\Mamiko\Desktop\Life Raft International\stripe-data-consolidation\.venv\lib\site-packages\matplotlib\__init__.py:1476, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1473 @functools.wraps(func)
#    1474 def inner(ax, *args, data=None, **kwargs):
#    1475     if data is None:
# -> 1476         return func(
#    1477             ax,
#    1478             *map(sanitize_sequence, args),
#    1479             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1481     bound = new_sig.bind(ax, *args, **kwargs)
#    1482     auto_label = (bound.arguments.get(label_namer)
#    1483                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Mamiko\Desktop\Life Raft International\stripe-data-consolidation\.venv\lib\site-packages\matplotlib\axes\_axes.py:4901, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4897         keys_str = ", ".join(f"'{k}'" for k in extra_keys)
#    4898         _api.warn_external(
#    4899             "No data for colormapping provided via 'c'. "
#    4900             f"Parameters {keys_str} will be ignored")
# -> 4901 collection._internal_update(kwargs)
#    4903 # Classic mode only:
#    4904 # ensure there are margins to allow for the
#    4905 # finite size of the symbols.  In v2.x, margins
#    4906 # are present by default, so we disable this
#    4907 # scatter-specific override.
#    4908 if mpl.rcParams['_internal.classic_mode']:
#
# File c:\Users\Mamiko\Desktop\Life Raft International\stripe-data-consolidation\.venv\lib\site-packages\matplotlib\artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File c:\Users\Mamiko\Desktop\Life Raft International\stripe-data-consolidation\.venv\lib\site-packages\matplotlib\artist.py:1190, in Artist._update_props(self, props, errfmt)
#    1188             func = getattr(self, f"set_{k}", None)
#    1189             if not callable(func):
# -> 1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
#    1192             ret.append(func(v))
#    1193 if ret:
#
# AttributeError: PathCollection.set() got an unexpected keyword argument 'markersize'

# %% [markdown]
# Visualising stopped/cancelled donations

# %%
#fig, ax = plt.subplots(figsize=(10,10), facecolor="grey", layout="tight")

#unique_customers=set(df["customer_id"].tolist())

#print(len(unique_customers))

#df.plot(x="created_utc", y="amount", kind="scatter", ax=ax, c="red")
