# %% [markdown]
# ## Recurring Donations
#
# ### Overview
#
# Analyse a single recurring donor transaction.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_parquet('full_data.parquet', engine="pyarrow")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1057 entries, 0 to 1056
# Data columns (total 10 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   balance_transaction_id                         1057 non-null   object
#  1   description                                    1057 non-null   object
#  2   created_utc                                    1057 non-null   datetime64[ns]
#  3   amount                                         1037 non-null   float64
#  4   currency                                       1057 non-null   object
#  5   fee                                            1057 non-null   float64
#  6   customer_id                                    920 non-null    object
#  7   customer_email                                 991 non-null    object
#  8   customer_name                                  991 non-null    object
#  9   payment_metadata[donorbox_recurring_donation]  1037 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 82.7+ KB

# %% [markdown]
# Filtering certain `customer_id`.
#
# `sort_values` by `created_utc` datetime value
#
# View the top and bottom of the `df`

# %%
df=df.loc[df["customer_id"].notnull()]

unique_customers=set(df["customer_id"].tolist())

print(len(unique_customers))

for customer in unique_customers:
    customer_df = df.loc[df["customer_id"] == customer]
 
    df.sort_values(by="created_utc", inplace=True, ascending=True)
    
    fig, ax = plt.subplots(figsize=(10,10), facecolor="grey", layout="tight")
    df.plot(x="created_utc", y="amount", kind="scatter", ax=ax, c="red")
# Out:
# 33
# cus_FzW5fWXnzYgrHn
# cus_I1tH2cEnCHxCTZ
# cus_GuRlmpeFkhmvry
# cus_Fzvf8cTb9cH1cz
# cus_JsmnstWcam5eqr
# cus_HEknffrlsfeF6l
# cus_Fs6eaj2AR7S8B0
# cus_Fz8vTZtLmLqPIb
# cus_PWeG1Vu2jhwLlS
# cus_JGmm4Q0GPxHiiY
# cus_RSFAfEPnza9Nn9
# cus_U5u6NZpiWV8E44
# cus_FuG5aO33vVc3jz
# cus_FsOguMdzqqREPq
# cus_KxbcZfawloKyQo
# cus_LgN9WhXeg7DaUB
# cus_G0cvTN74yGllPE
# cus_FqvD5sd1xLayOx
# cus_JzqJbkccDnvIqV
# cus_FqvJ444tZINA05
# cus_GpkiYfzHULt6sZ
# cus_G5wg1E3euJHYFm
# cus_Fud5UfS4eywmQO
# cus_NIog584QLf4HKd
# C:\Users\Mamiko\AppData\Local\Temp\ipykernel_21676\2721045798.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(10,10), facecolor="grey", layout="tight")
# cus_FzA6idMVSxEkMe
# cus_MXohuWTh7HcYTV
# cus_Fy2nFDlA13F3XG
# cus_J2GJtjR5rS18dw
# cus_G0c1mpDNfxWZHd
# cus_IIIyuxRwFuaSUC
# cus_PJ4KA1DBFxUNgU
# cus_Ke0Y3VRoSvZMla
# cus_LFoZXD1Pf4h1XC

# %% [markdown]
# visualising stopped donations

# %%
#fig, ax = plt.subplots(figsize=(10,10), facecolor="grey", layout="tight")

#unique_customers=set(df["customer_id"].tolist())

#print(len(unique_customers))

#df.plot(x="created_utc", y="amount", kind="scatter", ax=ax, c="red")
