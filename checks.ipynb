# %%
import pandas as pd

df1 = pd.read_csv("../Stripe Statements/2022/August 2022.csv")
df2 = pd.read_csv("../Stripe Statements/2023/August 2023.csv")

# %%
print(len(df1.columns))
print(len(df2.columns))
# Out:
# 39
# 62

# %%
print(len(df1))
print(len(df2))
# Out:
# 22
# 23

# %%
df1_cols = df1.columns.tolist()
df2_cols = df2.columns.tolist()

if df1_cols == df2_cols:
    cols_df = pd.DataFrame.from_dict({
        "2022": df1_cols,
        "2023": df2_cols
    })
    cols_df
else:
    print(df1_cols)
    print(df2_cols)
# Out:
# ['id', 'Description', 'Seller Message', 'Created (UTC)', 'Amount', 'Amount Refunded', 'Currency', 'Converted Amount', 'Converted Amount Refunded', 'Fee', 'Taxes On Fee', 'Converted Currency', 'Status', 'Statement Descriptor', 'Customer ID', 'Customer Description', 'Customer Email', 'Captured', 'Card ID', 'Invoice ID', 'Transfer', 'donorbox_address (metadata)', 'donorbox_campaign (metadata)', 'donorbox_city (metadata)', 'donorbox_email (metadata)', 'donorbox_first_name (metadata)', 'donorbox_first_recurring_charge (metadata)', 'donorbox_last_name (metadata)', 'donorbox_name (metadata)', 'donorbox_postal_code (metadata)', 'donorbox_recurring_donation (metadata)', 'donorbox_state (metadata)', 'donorbox_donor_id (metadata)', 'donorbox_phone (metadata)', 'donorbox_form_id (metadata)', 'donorbox_donation_type (metadata)', 'donorbox_plan_interval (metadata)', 'donorbox_gift_aid (metadata)', 'donorbox_idempotency_key (metadata)']
# ...

# %%
df = pd.read_csv('full_data.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1057 entries, 0 to 1056
# Data columns (total 10 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   balance_transaction_id                         1057 non-null   object
#  1   description                                    1057 non-null   object
#  2   created_utc                                    1057 non-null   object
#  3   amount                                         1037 non-null   float64
#  4   currency                                       1057 non-null   object
#  5   fee                                            1057 non-null   float64
#  6   customer_id                                    920 non-null    object
#  7   customer_email                                 991 non-null    object
#  8   customer_name                                  991 non-null    object
# ...

# %%
df["created_utc"] = pd.to_datetime(df["created_utc"], format="mixed", errors="raise")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1057 entries, 0 to 1056
# Data columns (total 10 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   balance_transaction_id                         1057 non-null   object
#  1   description                                    1057 non-null   object
#  2   created_utc                                    1057 non-null   datetime64[ns]
#  3   amount                                         1037 non-null   float64
#  4   currency                                       1057 non-null   object
#  5   fee                                            1057 non-null   float64
#  6   customer_id                                    920 non-null    object
#  7   customer_email                                 991 non-null    object
#  8   customer_name                                  991 non-null    object
# ...
